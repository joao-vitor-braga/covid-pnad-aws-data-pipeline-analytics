# %%
import sys
from awsglue.transforms import *
from awsglue.utils import getResolvedOptions
from pyspark.context import SparkContext
from awsglue.context import GlueContext
from awsglue.job import Job
from awsgluedq.transforms import EvaluateDataQuality

args = getResolvedOptions(sys.argv, ['JOB_NAME'])
sc = SparkContext()
glueContext = GlueContext(sc)
spark = glueContext.spark_session
job = Job(glueContext)
job.init(args['JOB_NAME'], args)

# Default ruleset used by all target nodes with data quality enabled
DEFAULT_DATA_QUALITY_RULESET = """
    Rules = [
        ColumnCount > 0
    ]
"""

# Script generated for node COVID_082020
COVID_082020_node1773357282645 = glueContext.create_dynamic_frame.from_options(format_options={"quoteChar": "\"", "withHeader": True, "separator": ",", "optimizePerformance": False}, connection_type="s3", format="csv", connection_options={"paths": ["s3://lab-727776330445/data-input/COVID_082020/"], "recurse": True}, transformation_ctx="COVID_082020_node1773357282645")

# Script generated for node COVID_092020
COVID_092020_node1773357282148 = glueContext.create_dynamic_frame.from_options(format_options={"quoteChar": "\"", "withHeader": True, "separator": ",", "optimizePerformance": False}, connection_type="s3", format="csv", connection_options={"paths": ["s3://lab-727776330445/data-input/COVID_092020/"], "recurse": True}, transformation_ctx="COVID_092020_node1773357282148")

# Script generated for node COVID_072020
COVID_072020_node1773357328300 = glueContext.create_dynamic_frame.from_options(format_options={"quoteChar": "\"", "withHeader": True, "separator": ",", "optimizePerformance": False}, connection_type="s3", format="csv", connection_options={"paths": ["s3://lab-727776330445/data-input/COVID_072020/"], "recurse": True}, transformation_ctx="COVID_072020_node1773357328300")

# Script generated for node COVID_082020
EvaluateDataQuality().process_rows(frame=COVID_082020_node1773357282645, ruleset=DEFAULT_DATA_QUALITY_RULESET, publishing_options={"dataQualityEvaluationContext": "EvaluateDataQuality_node1773357241146", "enableDataQualityResultsPublishing": True}, additional_options={"dataQualityResultsPublishing.strategy": "BEST_EFFORT", "observations.scope": "ALL"})
COVID_082020_node1773358804099 = glueContext.getSink(path="s3://lab-727776330445/data-output/bronze/", connection_type="s3", updateBehavior="UPDATE_IN_DATABASE", partitionKeys=["Ano"], enableUpdateCatalog=True, transformation_ctx="COVID_082020_node1773358804099")
COVID_082020_node1773358804099.setCatalogInfo(catalogDatabase="default",catalogTableName="COVID_Bronze")
COVID_082020_node1773358804099.setFormat("glueparquet", compression="snappy")
COVID_082020_node1773358804099.writeFrame(COVID_082020_node1773357282645)
# Script generated for node COVID_092020
EvaluateDataQuality().process_rows(frame=COVID_092020_node1773357282148, ruleset=DEFAULT_DATA_QUALITY_RULESET, publishing_options={"dataQualityEvaluationContext": "EvaluateDataQuality_node1773357241146", "enableDataQualityResultsPublishing": True}, additional_options={"dataQualityResultsPublishing.strategy": "BEST_EFFORT", "observations.scope": "ALL"})
COVID_092020_node1773359049847 = glueContext.getSink(path="s3://lab-727776330445/data-output/bronze/", connection_type="s3", updateBehavior="UPDATE_IN_DATABASE", partitionKeys=["Ano"], enableUpdateCatalog=True, transformation_ctx="COVID_092020_node1773359049847")
COVID_092020_node1773359049847.setCatalogInfo(catalogDatabase="default",catalogTableName="COVID_Bronze")
COVID_092020_node1773359049847.setFormat("glueparquet", compression="snappy")
COVID_092020_node1773359049847.writeFrame(COVID_092020_node1773357282148)
# Script generated for node COVID_072020
EvaluateDataQuality().process_rows(frame=COVID_072020_node1773357328300, ruleset=DEFAULT_DATA_QUALITY_RULESET, publishing_options={"dataQualityEvaluationContext": "EvaluateDataQuality_node1773357241146", "enableDataQualityResultsPublishing": True}, additional_options={"dataQualityResultsPublishing.strategy": "BEST_EFFORT", "observations.scope": "ALL"})
COVID_072020_node1773357814545 = glueContext.getSink(path="s3://lab-727776330445/data-output/bronze/", connection_type="s3", updateBehavior="UPDATE_IN_DATABASE", partitionKeys=["Ano"], enableUpdateCatalog=True, transformation_ctx="COVID_072020_node1773357814545")
COVID_072020_node1773357814545.setCatalogInfo(catalogDatabase="default",catalogTableName="COVID_Bronze")
COVID_072020_node1773357814545.setFormat("glueparquet", compression="snappy")
COVID_072020_node1773357814545.writeFrame(COVID_072020_node1773357328300)
job.commit()
